# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms, datasets
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# %%
image_size = 227
num_epochs = 10
batch_size = 64

device = ('cuda' if torch.cuda.is_available() else 'cpu')
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print(torch.__version__)
print(device)
# Out:
# 1.13.1+cu116
# cuda

# %%
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor()
])

# %%
train_data = datasets.FashionMNIST(
    root = 'data',
    train = True,
    download = True,
    transform = transform
)

test_data = datasets.FashionMNIST(
    root = 'data',
    train = False,
    download = True,
    transform = transform
)

# %%
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=True)

# %%
next(iter(train_loader))[0].shape
# Out:
# torch.Size([64, 1, 227, 227])

# %%
class AlexNetFashionMNIST(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=96, kernel_size=11, stride=4, padding=0),
            #input_size : 1x227x227
            #kernel_number : 96
            #output_w : ((227-11)/4) + 1) = 55
            #output_size : 96x55x55
            nn.ReLU(), # size 동일
            nn.MaxPool2d(3,2)
            #((55-3)/2)+1) = 27
            #최종 96x27x27 feature map 생성 
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=96, out_channels=256, kernel_size=5, stride=1, padding=2),
            #256x27x27
            nn.ReLU(),#256x27x27
            nn.MaxPool2d(3, 2)
            #256x13x13
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=256, out_channels=384, kernel_size=3, stride=1, padding=1),
            #13 유지
            nn.ReLU()
            #384x13x13
        )
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=384, out_channels=384, kernel_size=3, stride=1, padding=1),
            #13 유지
            nn.ReLU()
            #384x13x13
        )
        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(3, 2)# 13 -> 6
            #256x6x6
        )
        
        
        self.fc1 = nn.Linear(in_features=256*6*6, out_features=4096)
        self.fc2 = nn.Linear(4096, 4096)
        self.fc3 = nn.Linear(4096,10)
    
    
    def forward(self,x): #input_size = 64x1x227x227
        out = self.conv1(x)
        out = self.conv2(out)
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.conv5(out)
        out = out.view(out.size(0),-1)# 64x(256*6*6)
        
        out = F.relu(self.fc1(out))
        out = F.dropout(out, 0.5)
        out = F.relu(self.fc2(out))
        out = F.dropout(out, 0.5)
        out = self.fc3(out)
        out = F.log_softmax(out, dim=1)
        
        return out

# %%
model = AlexNetFashionMNIST().to(device)
criterion = F.nll_loss
optimizer = optim.Adam(model.parameters())

# %%
from torchsummary import summary as s

s(model, (1,227,227), batch_size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [64, 96, 55, 55]          11,712
#               ReLU-2           [64, 96, 55, 55]               0
#          MaxPool2d-3           [64, 96, 27, 27]               0
#             Conv2d-4          [64, 256, 27, 27]         614,656
#               ReLU-5          [64, 256, 27, 27]               0
#          MaxPool2d-6          [64, 256, 13, 13]               0
#             Conv2d-7          [64, 384, 13, 13]         885,120
#               ReLU-8          [64, 384, 13, 13]               0
#             Conv2d-9          [64, 384, 13, 13]       1,327,488
#              ReLU-10          [64, 384, 13, 13]               0
#            Conv2d-11          [64, 256, 13, 13]         884,992
#              ReLU-12          [64, 256, 13, 13]               0
#         MaxPool2d-13            [64, 256, 6, 6]               0
#            Linear-14                 [64, 4096]      37,752,832
#            Linear-15                 [64, 4096]      16,781,312
#            Linear-16                   [64, 10]          40,970
# ================================================================
# Total params: 58,299,082
# Trainable params: 58,299,082
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 12.58
# Forward/backward pass size (MB): 698.65
# Params size (MB): 222.39
# Estimated Total Size (MB): 933.62
# ----------------------------------------------------------------

# %%
def train(model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data,target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)

        output = model(data)
        loss = criterion(output,target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (batch_idx+1)%30 == 0:
            print(f'Train Epoch: {epoch} {100*(batch_idx+1)*batch_size/len(train_loader.dataset):.6f}%')

# %%
def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output,target,reduction='sum').item()
            pred = output.max(1)[1]
            correct += pred.eq(target).sum().item()
        
        test_loss /= len(test_loader.dataset)
    
        print(f"\nTest set: Average Loss:{test_loss:.4f}, Accuracy: {100 * correct / len(test_loader.dataset)}%")
        print('='*50)

# %%
for epoch in range(1,num_epochs):
    train(model, device, train_loader, optimizer, epoch)
    test(model, device, test_loader)
# Out:
# Train Epoch: 1 [3.200000]
# Train Epoch: 1 [6.400000]
# Train Epoch: 1 [9.600000]
# Train Epoch: 1 [12.800000]
# Train Epoch: 1 [16.000000]
# Train Epoch: 1 [19.200000]
# Train Epoch: 1 [22.400000]
# Train Epoch: 1 [25.600000]
# Train Epoch: 1 [28.800000]
# Train Epoch: 1 [32.000000]
# Train Epoch: 1 [35.200000]
# Train Epoch: 1 [38.400000]
# Train Epoch: 1 [41.600000]
# Train Epoch: 1 [44.800000]
# Train Epoch: 1 [48.000000]
# Train Epoch: 1 [51.200000]
# Train Epoch: 1 [54.400000]
# Train Epoch: 1 [57.600000]
# Train Epoch: 1 [60.800000]
# Train Epoch: 1 [64.000000]
# Train Epoch: 1 [67.200000]
# Train Epoch: 1 [70.400000]
# Train Epoch: 1 [73.600000]
# Train Epoch: 1 [76.800000]
# Train Epoch: 1 [80.000000]
# Train Epoch: 1 [83.200000]
# Train Epoch: 1 [86.400000]
# Train Epoch: 1 [89.600000]
# Train Epoch: 1 [92.800000]
# Train Epoch: 1 [96.000000]
# Train Epoch: 1 [99.200000]
#
# Test set: Average Loss:0.3800, Accuracy: 85.98%
# ==================================================
# Train Epoch: 2 [3.200000]
# Train Epoch: 2 [6.400000]
# Train Epoch: 2 [9.600000]
# Train Epoch: 2 [12.800000]
# Train Epoch: 2 [16.000000]
# Train Epoch: 2 [19.200000]
# Train Epoch: 2 [22.400000]
# Train Epoch: 2 [25.600000]
# Train Epoch: 2 [28.800000]
# Train Epoch: 2 [32.000000]
# Train Epoch: 2 [35.200000]
# Train Epoch: 2 [38.400000]
# Train Epoch: 2 [41.600000]
# Train Epoch: 2 [44.800000]
# Train Epoch: 2 [48.000000]
# Train Epoch: 2 [51.200000]
# Train Epoch: 2 [54.400000]
# Train Epoch: 2 [57.600000]
# Train Epoch: 2 [60.800000]
# Train Epoch: 2 [64.000000]
# Train Epoch: 2 [67.200000]
# Train Epoch: 2 [70.400000]
# Train Epoch: 2 [73.600000]
# Train Epoch: 2 [76.800000]
# Train Epoch: 2 [80.000000]
# Train Epoch: 2 [83.200000]
# Train Epoch: 2 [86.400000]
# Train Epoch: 2 [89.600000]
# Train Epoch: 2 [92.800000]
# Train Epoch: 2 [96.000000]
# Train Epoch: 2 [99.200000]
#
# Test set: Average Loss:0.3323, Accuracy: 88.1%
# ==================================================
# Train Epoch: 3 [3.200000]
# Train Epoch: 3 [6.400000]
# Train Epoch: 3 [9.600000]
# Train Epoch: 3 [12.800000]
# Train Epoch: 3 [16.000000]
# Train Epoch: 3 [19.200000]
# Train Epoch: 3 [22.400000]
# Train Epoch: 3 [25.600000]
# Train Epoch: 3 [28.800000]
# Train Epoch: 3 [32.000000]
# Train Epoch: 3 [35.200000]
# Train Epoch: 3 [38.400000]
# Train Epoch: 3 [41.600000]
# Train Epoch: 3 [44.800000]
# Train Epoch: 3 [48.000000]
# Train Epoch: 3 [51.200000]
# Train Epoch: 3 [54.400000]
# Train Epoch: 3 [57.600000]
# Train Epoch: 3 [60.800000]
# Train Epoch: 3 [64.000000]
# Train Epoch: 3 [67.200000]
# Train Epoch: 3 [70.400000]
# Train Epoch: 3 [73.600000]
# Train Epoch: 3 [76.800000]
# Train Epoch: 3 [80.000000]
# Train Epoch: 3 [83.200000]
# Train Epoch: 3 [86.400000]
# Train Epoch: 3 [89.600000]
# Train Epoch: 3 [92.800000]
# Train Epoch: 3 [96.000000]
# Train Epoch: 3 [99.200000]
#
# Test set: Average Loss:0.2932, Accuracy: 89.29%
# ==================================================
# Train Epoch: 4 [3.200000]
# Train Epoch: 4 [6.400000]
# Train Epoch: 4 [9.600000]
# Train Epoch: 4 [12.800000]
# Train Epoch: 4 [16.000000]
# Train Epoch: 4 [19.200000]
# Train Epoch: 4 [22.400000]
# Train Epoch: 4 [25.600000]
# Train Epoch: 4 [28.800000]
# Train Epoch: 4 [32.000000]
# Train Epoch: 4 [35.200000]
# Train Epoch: 4 [38.400000]
# Train Epoch: 4 [41.600000]
# Train Epoch: 4 [44.800000]
# Train Epoch: 4 [48.000000]
# Train Epoch: 4 [51.200000]
# Train Epoch: 4 [54.400000]
# Train Epoch: 4 [57.600000]
# Train Epoch: 4 [60.800000]
# Train Epoch: 4 [64.000000]
# Train Epoch: 4 [67.200000]
# Train Epoch: 4 [70.400000]
# Train Epoch: 4 [73.600000]
# Train Epoch: 4 [76.800000]
# Train Epoch: 4 [80.000000]
# Train Epoch: 4 [83.200000]
# Train Epoch: 4 [86.400000]
# Train Epoch: 4 [89.600000]
# Train Epoch: 4 [92.800000]
# Train Epoch: 4 [96.000000]
# Train Epoch: 4 [99.200000]
#
# Test set: Average Loss:0.2842, Accuracy: 89.96%
# ==================================================
# Train Epoch: 5 [3.200000]
# Train Epoch: 5 [6.400000]
# Train Epoch: 5 [9.600000]
# Train Epoch: 5 [12.800000]
# Train Epoch: 5 [16.000000]
# Train Epoch: 5 [19.200000]
# Train Epoch: 5 [22.400000]
# Train Epoch: 5 [25.600000]
# Train Epoch: 5 [28.800000]
# Train Epoch: 5 [32.000000]
# Train Epoch: 5 [35.200000]
# Train Epoch: 5 [38.400000]
# Train Epoch: 5 [41.600000]
# Train Epoch: 5 [44.800000]
# Train Epoch: 5 [48.000000]
# Train Epoch: 5 [51.200000]
# Train Epoch: 5 [54.400000]
# Train Epoch: 5 [57.600000]
# Train Epoch: 5 [60.800000]
# Train Epoch: 5 [64.000000]
# Train Epoch: 5 [67.200000]
# Train Epoch: 5 [70.400000]
# Train Epoch: 5 [73.600000]
# Train Epoch: 5 [76.800000]
# Train Epoch: 5 [80.000000]
# Train Epoch: 5 [83.200000]
# Train Epoch: 5 [86.400000]
# Train Epoch: 5 [89.600000]
# Train Epoch: 5 [92.800000]
# Train Epoch: 5 [96.000000]
# Train Epoch: 5 [99.200000]
#
# Test set: Average Loss:0.2899, Accuracy: 89.45%
# ==================================================
# Train Epoch: 6 [3.200000]
# Train Epoch: 6 [6.400000]
# Train Epoch: 6 [9.600000]
# Train Epoch: 6 [12.800000]
# Train Epoch: 6 [16.000000]
# Train Epoch: 6 [19.200000]
# Train Epoch: 6 [22.400000]
# Train Epoch: 6 [25.600000]
# Train Epoch: 6 [28.800000]
# Train Epoch: 6 [32.000000]
# Train Epoch: 6 [35.200000]
# Train Epoch: 6 [38.400000]
# Train Epoch: 6 [41.600000]
# Train Epoch: 6 [44.800000]
# Train Epoch: 6 [48.000000]
# Train Epoch: 6 [51.200000]
# Train Epoch: 6 [54.400000]
# Train Epoch: 6 [57.600000]
# Train Epoch: 6 [60.800000]
# Train Epoch: 6 [64.000000]
# Train Epoch: 6 [67.200000]
# Train Epoch: 6 [70.400000]
# Train Epoch: 6 [73.600000]
# Train Epoch: 6 [76.800000]
# Train Epoch: 6 [80.000000]
# Train Epoch: 6 [83.200000]
# Train Epoch: 6 [86.400000]
# Train Epoch: 6 [89.600000]
# Train Epoch: 6 [92.800000]
# Train Epoch: 6 [96.000000]
# Train Epoch: 6 [99.200000]
#
# Test set: Average Loss:0.2982, Accuracy: 89.39%
# ==================================================
# Train Epoch: 7 [3.200000]
# Train Epoch: 7 [6.400000]
# Train Epoch: 7 [9.600000]
# Train Epoch: 7 [12.800000]
# Train Epoch: 7 [16.000000]
# Train Epoch: 7 [19.200000]
# Train Epoch: 7 [22.400000]
# Train Epoch: 7 [25.600000]
# Train Epoch: 7 [28.800000]
# Train Epoch: 7 [32.000000]
# Train Epoch: 7 [35.200000]
# Train Epoch: 7 [38.400000]
# Train Epoch: 7 [41.600000]
# Train Epoch: 7 [44.800000]
# Train Epoch: 7 [48.000000]
# Train Epoch: 7 [51.200000]
# Train Epoch: 7 [54.400000]
# Train Epoch: 7 [57.600000]
# Train Epoch: 7 [60.800000]
# Train Epoch: 7 [64.000000]
# Train Epoch: 7 [67.200000]
# Train Epoch: 7 [70.400000]
# Train Epoch: 7 [73.600000]
# Train Epoch: 7 [76.800000]
# Train Epoch: 7 [80.000000]
# Train Epoch: 7 [83.200000]
# Train Epoch: 7 [86.400000]
# Train Epoch: 7 [89.600000]
# Train Epoch: 7 [92.800000]
# Train Epoch: 7 [96.000000]
# Train Epoch: 7 [99.200000]
#
# Test set: Average Loss:0.2919, Accuracy: 90.03%
# ==================================================
# Train Epoch: 8 [3.200000]
# Train Epoch: 8 [6.400000]
# Train Epoch: 8 [9.600000]
# Train Epoch: 8 [12.800000]
# Train Epoch: 8 [16.000000]
# Train Epoch: 8 [19.200000]
# Train Epoch: 8 [22.400000]
# Train Epoch: 8 [25.600000]
# Train Epoch: 8 [28.800000]
# Train Epoch: 8 [32.000000]
# Train Epoch: 8 [35.200000]
# Train Epoch: 8 [38.400000]
# Train Epoch: 8 [41.600000]
# Train Epoch: 8 [44.800000]
# Train Epoch: 8 [48.000000]
# Train Epoch: 8 [51.200000]
# Train Epoch: 8 [54.400000]
# Train Epoch: 8 [57.600000]
# Train Epoch: 8 [60.800000]
# Train Epoch: 8 [64.000000]
# Train Epoch: 8 [67.200000]
# Train Epoch: 8 [70.400000]
# Train Epoch: 8 [73.600000]
# Train Epoch: 8 [76.800000]
# Train Epoch: 8 [80.000000]
# Train Epoch: 8 [83.200000]
# Train Epoch: 8 [86.400000]
# Train Epoch: 8 [89.600000]
# Train Epoch: 8 [92.800000]
# Train Epoch: 8 [96.000000]
# Train Epoch: 8 [99.200000]
#
# Test set: Average Loss:0.2886, Accuracy: 89.85%
# ==================================================
# Train Epoch: 9 [3.200000]
# Train Epoch: 9 [6.400000]
# Train Epoch: 9 [9.600000]
# Train Epoch: 9 [12.800000]
# Train Epoch: 9 [16.000000]
# Train Epoch: 9 [19.200000]
# Train Epoch: 9 [22.400000]
# Train Epoch: 9 [25.600000]
# Train Epoch: 9 [28.800000]
# Train Epoch: 9 [32.000000]
# Train Epoch: 9 [35.200000]
# Train Epoch: 9 [38.400000]
# Train Epoch: 9 [41.600000]
# Train Epoch: 9 [44.800000]
# Train Epoch: 9 [48.000000]
# Train Epoch: 9 [51.200000]
# Train Epoch: 9 [54.400000]
# Train Epoch: 9 [57.600000]
# Train Epoch: 9 [60.800000]
# Train Epoch: 9 [64.000000]
# Train Epoch: 9 [67.200000]
# Train Epoch: 9 [70.400000]
# Train Epoch: 9 [73.600000]
# Train Epoch: 9 [76.800000]
# Train Epoch: 9 [80.000000]
# Train Epoch: 9 [83.200000]
# Train Epoch: 9 [86.400000]
# Train Epoch: 9 [89.600000]
# Train Epoch: 9 [92.800000]
# Train Epoch: 9 [96.000000]
# Train Epoch: 9 [99.200000]
#
# Test set: Average Loss:0.2980, Accuracy: 90.0%
# ==================================================
